# %%
# Q1. Creating a DataFrame
#Create a Pandas DataFrame using a Python dictionary with the following columns:
#Product
#Region
#Sales
#Quantity

import pandas as pd

# Creating the dictionary
data = {
    'Product': ['Laptop', 'Tablet', 'Monitor', 'Keyboard', 'Phone'],
    'Region': ['West', 'South', 'East', 'North', 'South'],
    'Sales': [1056, 904, 1269, 777, 2028],
    'Quantity': [2, 7, 8, 8, 4]
}

df = pd.DataFrame(data)

print(df)
# Out:
#     Product Region  Sales  Quantity
# 0    Laptop   West   1056         2
# 1    Tablet  South    904         7
# 2   Monitor   East   1269         8
# 3  Keyboard  North    777         8
# 4     Phone  South   2028         4

# %%
# Q2. Data Inspection
# Load the dataset from the CSV file
df_retail = pd.read_csv('/content/Retail_dataset.csv')

print('Dataset loaded successfully.')
# Out:
# Dataset loaded successfully.

# %% [markdown]
# ### Q2 Displaying the first 5 rows of the dataset:

# %%
#Q.2 Display the first 5 rows
display(df_retail.head())
# Out:
#    Order_ID Customer   Product Region  Sales  Quantity
# 0      1001    Sneha    Laptop   West   1056         2
# 1      1002     Neha    Tablet  South    904         7
# 2      1003    Meera    Laptop  South   1597         5
# 3      1004    Rohan  Keyboard  North    777         8
# 4      1005    Priya     Phone  South   2028         4

# %% [markdown]
# ### Displaying the last 5 rows of the dataset:

# %%
# Display the last 5 rows
display(df_retail.tail())
# Out:
#     Order_ID Customer   Product Region  Sales  Quantity
# 85      1086    Pooja    Laptop   East   1330         2
# 86      1087    Anita  Keyboard   West    741         3
# 87      1088    Karan   Monitor   East    875         2
# 88      1089      Raj    Tablet  North   2213         5
# 89      1090    Priya    Laptop  South   1270         2

# %% [markdown]
# ### Showing the structure of the dataset using `info()`:

# %%
# Show the structure of the dataset
df_retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Order_ID  90 non-null     int64
#  1   Customer  90 non-null     object
#  2   Product   90 non-null     object
#  3   Region    90 non-null     object
#  4   Sales     90 non-null     int64
#  5   Quantity  90 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 4.3+ KB

# %% [markdown]
# ### Displaying the shape of the dataset:

# %%
# Display the shape of the dataset
print(f"Shape of the dataset: {df_retail.shape}")
# Out:
# Shape of the dataset: (90, 6)

# %% [markdown]
# ### Q3. Column Selection

# %%
# Select and display only 'Product', 'Region', and 'Sales' columns
selected_columns = df_retail[['Product', 'Region', 'Sales']]
display(selected_columns)
# Out:
#      Product Region  Sales
# 0     Laptop   West   1056
# 1     Tablet  South    904
# 2     Laptop  South   1597
# 3   Keyboard  North    777
# 4      Phone  South   2028
# ..       ...    ...    ...
# 85    Laptop   East   1330
# 86  Keyboard   West    741
# 87   Monitor   East    875
# 88    Tablet  North   2213
# 89    Laptop  South   1270
#
# [90 rows x 3 columns]

# %% [markdown]
# ### Q4. Indexing using `.loc`

# %%
# Display the row with index 10
print("Row with index 10:")
display(df_retail.loc[10])
# Out:
# Row with index 10:
# Order_ID       1011
# Customer        Raj
# Product     Monitor
# Region        North
# Sales          1693
# Quantity          6
# Name: 10, dtype: object

# %%
# Display the Sales value of the row with index 20
print("Sales value of the row with index 20:")
display(df_retail.loc[20, 'Sales'])
# Out:
# Sales value of the row with index 20:
# np.int64(1021)

# %% [markdown]
# ### Q5. Indexing using `.iloc`

# %%
# Display the first 6 rows and first 4 columns
print("First 6 rows and first 4 columns:")
display(df_retail.iloc[0:6, 0:4])
# Out:
# First 6 rows and first 4 columns:
#    Order_ID Customer   Product Region
# 0      1001    Sneha    Laptop   West
# 1      1002     Neha    Tablet  South
# 2      1003    Meera    Laptop  South
# 3      1004    Rohan  Keyboard  North
# 4      1005    Priya     Phone  South
# 5      1006    Rahul    Tablet   West

# %%
# Display the Sales value from the 3rd row (index 2)
print("Sales value from the 3rd row:")
display(df_retail.iloc[2, 4])
# Out:
# Sales value from the 3rd row:
# np.int64(1597)

# %% [markdown]
# ### Q6. Row Slicing

# %% [markdown]
# #### Displaying the first 10 rows of the dataset:

# %%
# Display the first 10 rows
display(df_retail.head(10))
# Out:
#    Order_ID Customer   Product Region  Sales  Quantity
# 0      1001    Sneha    Laptop   West   1056         2
# 1      1002     Neha    Tablet  South    904         7
# 2      1003    Meera    Laptop  South   1597         5
# 3      1004    Rohan  Keyboard  North    777         8
# 4      1005    Priya     Phone  South   2028         4
# 5      1006    Rahul    Tablet   West    638         2
# 6      1007     Amit   Monitor  South   1004         7
# 7      1008    Sneha   Monitor   East   1269         8
# 8      1009    Priya     Phone  North    827         8
# 9      1010     Amit     Phone   West   1998         4

# %% [markdown]
# #### Q6 Displaying rows 15 to 25 of the dataset:

# %%
# Q6Display rows 15 to 25
display(df_retail[15:26])
# Out:
#     Order_ID Customer  Product Region  Sales  Quantity
# 15      1016    Karan  Monitor   West    796         3
# 16      1017     Neha   Laptop   East   2015         2
# 17      1018    Anita    Phone  North   1637         3
# 18      1019     Amit    Phone   East    748         7
# 19      1020     Neha   Laptop   West   1503         6
# 20      1021    Priya   Laptop  North   1021         4
# 21      1022      Raj   Tablet  South    886         7
# 22      1023    Rahul   Laptop  South   2267         3
# 23      1024    Karan  Monitor   East    814         7
# 24      1025    Meera  Monitor   West   1926         6
# 25      1026    Anita   Tablet   East    839         5

# %% [markdown]
# ### Q7. Filtering Data

# %% [markdown]
# #### Displaying rows where Region = "East":

# %%
# Filter for rows where Region is 'East'
display(df_retail[df_retail['Region'] == 'East'])
# Out:
#     Order_ID Customer   Product Region  Sales  Quantity
# 7       1008    Sneha   Monitor   East   1269         8
# 11      1012    Rahul    Laptop   East   1022         5
# 16      1017     Neha    Laptop   East   2015         2
# 18      1019     Amit     Phone   East    748         7
# 23      1024    Karan   Monitor   East    814         7
# 25      1026    Anita    Tablet   East    839         5
# 31      1032     Amit    Laptop   East   2226         6
# 34      1035     Amit    Tablet   East   2104         3
# 35      1036    Rohan     Phone   East   2136         8
# 36      1037      Raj     Phone   East   1650         4
# 37      1038     Amit   Monitor   East   1567         8
# 38      1039    Meera  Keyboard   East   2455         3
# 44      1045    Priya     Phone   East   1875         4
# 47      1048    Rohan   Monitor   East   1103         2
# 52      1053    Rahul    Laptop   East   2276         1
# 53      1054      Raj   Monitor   East   1420         2
# ...

# %% [markdown]
# #### Q6 Displaying rows where Sales > 1500:

# %%
# Filter for rows where Sales are greater than 1500
display(df_retail[df_retail['Sales'] > 1500])
# Out:
#     Order_ID Customer   Product Region  Sales  Quantity
# 2       1003    Meera    Laptop  South   1597         5
# 4       1005    Priya     Phone  South   2028         4
# 9       1010     Amit     Phone   West   1998         4
# 10      1011      Raj   Monitor  North   1693         6
# 13      1014    Rohan     Phone  South   2078         3
# 16      1017     Neha    Laptop   East   2015         2
# 17      1018    Anita     Phone  North   1637         3
# 19      1020     Neha    Laptop   West   1503         6
# 22      1023    Rahul    Laptop  South   2267         3
# 24      1025    Meera   Monitor   West   1926         6
# 26      1027    Vikas    Laptop  North   1864         8
# 27      1028    Vikas    Laptop  North   1551         3
# 29      1030    Rohan   Monitor   West   1932         5
# 31      1032     Amit    Laptop   East   2226         6
# 34      1035     Amit    Tablet   East   2104         3
# 35      1036    Rohan     Phone   East   2136         8
# ...

# %% [markdown]
# ### Q8. Multiple Condition Filtering

# %%
# Display rows where Region is 'West' and Sales is greater than 1200
display(df_retail[(df_retail['Region'] == 'West') & (df_retail['Sales'] > 1200)])
# Out:
#     Order_ID Customer   Product Region  Sales  Quantity
# 9       1010     Amit     Phone   West   1998         4
# 19      1020     Neha    Laptop   West   1503         6
# 24      1025    Meera   Monitor   West   1926         6
# 29      1030    Rohan   Monitor   West   1932         5
# 42      1043    Meera  Keyboard   West   1515         6
# 43      1044    Vikas    Laptop   West   2248         5
# 49      1050    Karan   Monitor   West   2034         7
# 55      1056    Rahul    Laptop   West   1481         1
# 58      1059    Karan    Tablet   West   2404         6
# 59      1060    Karan    Tablet   West   1651         2
# 63      1064    Pooja  Keyboard   West   2310         5
# 68      1069    Priya    Laptop   West   1422         6
# 69      1070    Rahul    Tablet   West   2134         5
# 73      1074    Meera  Keyboard   West   1429         7
# 83      1084    Rohan    Laptop   West   1204         5
# 84      1085     Neha   Monitor   West   1339         7

# %% [markdown]
# ### Q9. Descriptive Statistics

# %%
# Q9Generate descriptive statistics
descriptive_stats = df_retail.describe()
display(descriptive_stats)
# Out:
#           Order_ID        Sales   Quantity
# count    90.000000    90.000000  90.000000
# mean   1045.500000  1406.888889   4.700000
# std      26.124701   531.748302   2.179836
# min    1001.000000   515.000000   1.000000
# 25%    1023.250000   890.500000   3.000000
# 50%    1045.500000  1402.000000   5.000000
# 75%    1067.750000  1857.250000   7.000000
# max    1090.000000  2455.000000   8.000000

# %% [markdown]
# ### Q10. Aggregation Analysis

# %%
# Q10 Calculate total sales
total_sales = df_retail['Sales'].sum()

# Calculate average sales
average_sales = df_retail['Sales'].mean()

# Calculate maximum sales
max_sales = df_retail['Sales'].max()

# Calculate minimum sales
min_sales = df_retail['Sales'].min()

print(f"Total Sales: {total_sales:.2f}")
print(f"Average Sales: {average_sales:.2f}")
print(f"Maximum Sales: {max_sales:.2f}")
print(f"Minimum Sales: {min_sales:.2f}")
# Out:
# Total Sales: 126620.00
# Average Sales: 1406.89
# Maximum Sales: 2455.00
# Minimum Sales: 515.00

# %% [markdown]
# From the descriptive statistics above, we can identify:
#
# *   **Mean sales value:** `descriptive_stats.loc['mean', 'Sales']`
# *   **Maximum quantity sold:** `descriptive_stats.loc['max', 'Quantity']`
# *   **Minimum sales value:** `descriptive_stats.loc['min', 'Sales']`
